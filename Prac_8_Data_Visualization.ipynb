# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data['Cabin'] = data['Cabin'].fillna(data['Cabin'].mode()[0])

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='Survived', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='Pclass', data = data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='Pclass', hue='Survived', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='Embarked', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='Sex', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='Age', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='Fare', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='Pclass', data=data)
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='SibSp', data=data)
plt.tight_layout()

# %%
data['SibSp'].median()
# Out:
# np.float64(0.0)

# %%
sns.catplot(x='Pclass', y='Age', data=data, kind='box', height=2, aspect=1.5)

# %%
sns.catplot(x= 'Pclass', y = 'Fare', data=data, kind = 'strip', height=2, aspect=1.5)

# %%
sns.catplot(x='Sex', y='Fare', data=data, kind='box', height=2, aspect=1.5)

# %%
sns.catplot(x='Sex', y='Age', data=data, kind='box', height=2, aspect=1.5)

# %%
sns.catplot(x='Sex', y='Age', data=data, kind='strip', height=4, aspect=3)

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='Sex', y='Age', data=data)
plt.tight_layout()

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x='Fare', y='Pclass', data=data, hue='Survived')
plt.tight_layout()

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x='Survived', y='Fare', data=data)
plt.tight_layout()

# %%
sns.displot(data['Age'], height=2, aspect=1.5)

# %%
sns.displot(data['Fare'], height=2, aspect=1.5)

# %%
plt.figure(figsize=(2.5, 2))
sns.jointplot(x = "Survived", y = "Fare", kind = "scatter", data = data)

# %%
plt.figure(figsize=(3, 2.5))
tc = data.corr(numeric_only=True)
sns.heatmap(tc, cmap="YlGnBu")
plt.title('Correlation')
plt.tight_layout()

# %%
sns.catplot(x='Pclass', y='Fare', data=data, kind='bar', height=2, aspect=1.5)
